# %%
from tensorflow import keras
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
data = keras.datasets.fashion_mnist

# %%
(train_images, train_labels), (test_images, test_labels) = data.load_data()

# %%
class_names = ['T-shirt/top','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']

# %%
train_labels.shape
# Out:
# (60000,)

# %%
train_images = train_images/255.0
test_images = test_images/255.0

# %%
# add three layers of this model in a sequence
# they represent input layer, hidden layer and output layer repectively
model = keras.Sequential([keras.layers.Flatten(input_shape=(28,28)),
                         keras.layers.Dense(128,activation="relu"),
                         keras.layers.Dense(10,activation="softmax")
                         ])

# %%
model.compile(optimizer="adam",loss="sparse_categorical_crossentropy",metrics=["accuracy"])

# %%
model.fit(train_images, train_labels,epochs = 5)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 6s 94us/sample - loss: 0.2667 - accuracy: 0.9002
# Epoch 2/10
# 60000/60000 [==============================] - 6s 99us/sample - loss: 0.2546 - accuracy: 0.9046
# Epoch 3/10
# 60000/60000 [==============================] - 5s 88us/sample - loss: 0.2451 - accuracy: 0.9084
# Epoch 4/10
# 60000/60000 [==============================] - 6s 96us/sample - loss: 0.2360 - accuracy: 0.9111
# Epoch 5/10
# 60000/60000 [==============================] - 6s 93us/sample - loss: 0.2283 - accuracy: 0.9148
# Epoch 6/10
# 60000/60000 [==============================] - 6s 100us/sample - loss: 0.2201 - accuracy: 0.9174
# Epoch 7/10
# 60000/60000 [==============================] - 5s 90us/sample - loss: 0.2128 - accuracy: 0.9196
# Epoch 8/10
# 60000/60000 [==============================] - 6s 100us/sample - loss: 0.2075 - accuracy: 0.9221
# Epoch 9/10
# 60000/60000 [==============================] - 6s 99us/sample - loss: 0.2009 - accuracy: 0.9247
# Epoch 10/10
# 60000/60000 [==============================] - 6s 98us/sample - loss: 0.1961 - accuracy: 0.9264

# %%
test_loss, test_acc = model.evaluate(test_images,test_labels)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
prediction = model.predict(test_images)

# %%
for i in range(5):
    plt.grid(False)
    plt.imshow(test_images[i],cmap=plt.cm.binary)
    plt.xlabel("Actual: "+ class_names[test_labels[i]])
    plt.title("Prediction: "+class_names[np.argmax(prediction[i])])

# %%
class_names[np.argmax(prediction)]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-34-77e77f149ecb> in <module>
# ----> 1 class_names[np.argmax(prediction)]
#
# IndexError: list index out of range
