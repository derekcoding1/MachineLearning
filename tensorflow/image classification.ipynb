# %%
from tensorflow import keras
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
data = keras.datasets.fashion_mnist

# %%
(train_images, train_labels), (test_images, test_labels) = data.load_data()

# %%
class_names = ['T-shirt/top','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']

# %%
train_labels.shape
# Out:
# (60000,)

# %%
train_images = train_images/255.0
test_images = test_images/255.0

# %%
# add three layers of this model in a sequence
# they represent input layer, hidden layer and output layer repectively
model = keras.Sequential([keras.layers.Flatten(input_shape=(28,28)),
                         keras.layers.Dense(128,activation="relu"),
                         keras.layers.Dense(10,activation="softmax")
                         ])

# %%
model.compile(optimizer="adam",loss="sparse_categorical_crossentropy",metrics=["accuracy"])

# %%
model.fit(train_images, train_labels,epochs = 5)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 6s 101us/sample - loss: 0.3694 - accuracy: 0.8650
# Epoch 2/5
# 60000/60000 [==============================] - 5s 87us/sample - loss: 0.3317 - accuracy: 0.8787
# Epoch 3/5
# 60000/60000 [==============================] - 6s 95us/sample - loss: 0.3081 - accuracy: 0.8861
# Epoch 4/5
# 60000/60000 [==============================] - 6s 100us/sample - loss: 0.2924 - accuracy: 0.8931
# Epoch 5/5
# 60000/60000 [==============================] - 7s 112us/sample - loss: 0.2761 - accuracy: 0.8982

# %%
test_loss, test_acc = model.evaluate(test_images,test_labels)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
test_acc
# Out:
# 0.8738
